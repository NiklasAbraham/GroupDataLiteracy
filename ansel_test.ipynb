# %%
import pandas as pd

# %%
wiki_movies = pd.read_csv("wikidata_movies.csv")

# %%
wiki_movies.head()
# Out:
#                                               title          release_date  \
# 0                                 The Simple Things  1953-04-18T00:00:00Z
# 1                               Duck! Rabbit, Duck!  1953-01-01T00:00:00Z
# 2  The Crow and the Fox, the Cuckoo and the Rooster  1953-01-01T00:00:00Z
# 3                     Toot, Whistle, Plunk and Boom  1953-11-10T00:00:00Z
# 4                                  Canvas Back Duck  1953-01-01T00:00:00Z
#
#                             genre                              director  \
# 0                             NaN                Charles August Nichols
# 1                             NaN                           Chuck Jones
# 2                             NaN                        Ivan Aksenchuk
# 3  documentary film, musical film  Charles August Nichols, Ward Kimball
# 4                     boxing film                           Jack Hannah
#
#    duration    imdb_id        country  year
# ...

# %%
wiki_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1703 entries, 0 to 1702
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         1703 non-null   object
#  1   release_date  1703 non-null   object
#  2   genre         926 non-null    object
#  3   director      1310 non-null   object
#  4   duration      933 non-null    float64
#  5   imdb_id       1366 non-null   object
#  6   country       1522 non-null   object
#  7   year          1703 non-null   int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 106.6+ KB

# %%
import wikipediaapi

# %%
wiki = wikipediaapi.Wikipedia(user_agent="DataLiteracy (ansel-heng-yu.cheung@student.uni-tuebingen.de)", language='en')

# %%
page = wiki.page(wiki_movies.iloc[0]["title"])

# %%
page.exists()
# Out:
# True

# %%
print(page.title)
# Out:
# The Simple Things

# %%
print(page.section_by_title("Plot").text)
# Out:
# At the start of the cartoon, Mickey is seen whistling to the tune of the song "The Simple Things" while walking along a rocky seashore, fishing gear in hand. Pluto, sniffing behind him, spots a mussel as he tries to cover up miniature geysers along the way. The mussel then squirts water at him. Pluto barks at the mussel and the mussel barks back. The mussel gets trapped on Pluto's tail after they fight. He pulls the mussel up and attempts to shove it off his tail but instead, he pulls the mussel up and down like a yo-yo. The mussel accidentally gets stuck in his mouth.
# ...

# %%
for section in page.sections:
    print(section.title)
# Out:
# Plot
# Other appearances
# Voice cast
# Reception
# Home media
# See also
# References
# External links
