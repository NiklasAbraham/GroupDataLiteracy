# %%
import data_utils
import pandas as pd

DATA_DIR = "../../all_data_with_embeddings/data_final"

# %%
movies = data_utils.load_movie_data(DATA_DIR)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214682 entries, 0 to 214681
# Data columns (total 22 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   movie_id        214682 non-null  object
#  1   title           214682 non-null  object
#  2   summary         0 non-null       object
#  3   release_date    214682 non-null  object
#  4   genre           176286 non-null  object
#  5   director        190633 non-null  object
#  6   actors          145397 non-null  object
#  7   duration        131062 non-null  object
#  8   imdb_id         202057 non-null  object
#  9   country         205006 non-null  object
#  10  sitelinks       214682 non-null  object
#  11  wikipedia_link  214682 non-null  object
#  12  budget          8499 non-null    object
#  13  box_office      7685 non-null    object
#  14  awards          9746 non-null    object
#  15  set_in_period   3468 non-null    object
# ...

# %% [markdown]
# ## Problem with data - some rows are actually series episodes
#
# Examples:
#
# Row 150000: https://en.wikipedia.org/wiki/Pilot_(Up_All_Night)
#
# Row 122005: https://en.wikipedia.org/wiki/Pilot_(House)

# %%
movies.iloc[150000]["wikipedia_link"]
# Out:
# 'https://en.wikipedia.org/wiki/Pilot_(Up_All_Night)'

# %%
pilot_movies = movies[movies.wikipedia_link.str.contains("Pilot")]  # possibly pilots of series
pd.set_option("display.max_colwidth", None)
pilot_movies.wikipedia_link.iloc[50:60]
# Out:
# 117829           https://en.wikipedia.org/wiki/Pilot_(Supernatural)
# 118421          https://en.wikipedia.org/wiki/Pilot_(American_Dad!)
# 118640                  https://en.wikipedia.org/wiki/Pilot_(Bones)
# 119551        https://en.wikipedia.org/wiki/Pilot_(My_Name_Is_Earl)
# 120479                https://en.wikipedia.org/wiki/Pilot_(Numbers)
# 122005                  https://en.wikipedia.org/wiki/Pilot_(House)
# 123832           https://en.wikipedia.org/wiki/I_Want_to_Be_a_Pilot
# 123902    https://en.wikipedia.org/wiki/Pilot_(Friday_Night_Lights)
# 125031                  https://en.wikipedia.org/wiki/Pilot_(Psych)
# 125032                https://en.wikipedia.org/wiki/Pilot_(Numbers)
# Name: wikipedia_link, dtype: object

# %%
movies.iloc[122005]
# Out:
# movie_id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              
# ...
